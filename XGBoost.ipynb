# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset = pd.read_csv('kc_house_data.csv')
dataset.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
dataset.shape
# Out:
# (21613, 21)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
dataset.groupby('yr_built')['price'].median().plot()
plt.xlabel('Year Built')
plt.ylabel('Median House')
plt.title('House Price Vs Year Built')
# Out:
# Text(0.5, 1.0, 'House Price Vs Year Built')

# %%
dataset.groupby('yr_renovated')['price'].median().plot()
plt.xlabel('Year Built')
plt.ylabel('Median House')
plt.title('House Price Vs Year Built')
# Out:
# Text(0.5, 1.0, 'House Price Vs Year Built')

# %%
dataset['yr_renovated'] = np.where(dataset['yr_renovated'] == 0, dataset['yr_built'], dataset['yr_renovated'])

# %%
dataset.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
dataset.drop(['id'], axis = 1, inplace = True)
dataset.drop(['date'], axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#       price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ... -122.257           1340        5650
# 1  538000.0         3       2.25  ... -122.319           1690        7639
# 2  180000.0         2       1.00  ... -122.233           2720        8062
# 3  604000.0         4       3.00  ... -122.393           1360        5000
# 4  510000.0         3       2.00  ... -122.045           1800        7503
#
# [5 rows x 19 columns]

# %%
dataset.corr()
# Out:
#                   price  bedrooms  ...  sqft_living15  sqft_lot15
# price          1.000000  0.308350  ...       0.585379    0.082447
# bedrooms       0.308350  1.000000  ...       0.391638    0.029244
# bathrooms      0.525138  0.515884  ...       0.568634    0.087175
# sqft_living    0.702035  0.576671  ...       0.756420    0.183286
# sqft_lot       0.089661  0.031703  ...       0.144608    0.718557
# floors         0.256794  0.175429  ...       0.279885   -0.011269
# waterfront     0.266369 -0.006582  ...       0.086463    0.030703
# view           0.397293  0.079532  ...       0.280439    0.072575
# condition      0.036362  0.028472  ...      -0.092824   -0.003406
# grade          0.667434  0.356967  ...       0.713202    0.119248
# sqft_above     0.605567  0.477600  ...       0.731870    0.194050
# sqft_basement  0.323816  0.303093  ...       0.200355    0.017276
# yr_built       0.054012  0.154178  ...       0.326229    0.070958
# ...

# %%
dataset.groupby('yr_renovated')['price'].median().plot()
plt.xlabel('Year Built')
plt.ylabel('Median House')
plt.title('House Price Vs Year Built')
# Out:
# Text(0.5, 1.0, 'House Price Vs Year Built')

# %%
dataset['zipcode'].unique().count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-ea030f19e2ad> in <module>()
# ----> 1 dataset['zipcode'].unique().count
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
dataset.nunique()
# Out:
# price            4028
# bedrooms           13
# bathrooms          30
# sqft_living      1038
# sqft_lot         9782
# floors              6
# waterfront          2
# view                5
# condition           5
# grade              12
# sqft_above        946
# sqft_basement     306
# yr_built          116
# yr_renovated      116
# zipcode            70
# lat              5034
# long              752
# sqft_living15     777
# sqft_lot15       8689
# dtype: int64

# %%
dataset.groupby('floors')['price'].median().plot.bar()
plt.xlabel('floors')
plt.ylabel('Median House')
plt.title('House Price Vs Floors')
# Out:
# Text(0.5, 1.0, 'House Price Vs Floors')

# %%
dataset.groupby('bedrooms')['price'].median().plot.bar()
plt.xlabel('Bedrooms')
plt.ylabel('Median House')
plt.title('House Price Vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'House Price Vs Bedrooms')

# %%
plt.scatter(dataset['price'],dataset['sqft_living15'])

# %%
data['sqft_lot15'] = np.log(data['sqft_lot15'])

# %%
data['sqft_lot15'].hist()

# %%
data['sqft_lot15'].head()
# Out:
# 0    8.639411
# 1    8.941022
# 2    8.994917
# 3    8.517193
# 4    8.923058
# Name: sqft_lot15, dtype: float64

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X = dataset.drop('price', axis = 1)
y = dataset['price']

# %%
np.random.seed(35)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
model = XGBRegressor()
model.fit(X_train,y_train)
# Out:
# [10:52:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
y_preds = model.predict(X_test)
accuracy_score(y_test,y_preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-76098f9952ca> in <module>()
#       1 y_preds = model.predict(X_test)
# ----> 2 accuracy_score(y_test,y_preds)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ...

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...     long  sqft_living15  sqft_lot15
# 0         3       1.00         1180  ... -122.257           1340        5650
# 1         3       2.25         2570  ... -122.319           1690        7639
# 2         2       1.00          770  ... -122.233           2720        8062
# 3         4       3.00         1960  ... -122.393           1360        5000
# 4         3       2.00         1680  ... -122.045           1800        7503
#
# [5 rows x 18 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dataset.corr(),annot=True, fmt=".2f", linewidths=.5, ax=ax,cmap='RdYlGn')
plt.show()

# %%
#Dropping out the unnecessary features regarding to Correlation coefficient
dataset.drop(['zipcode','condition','long','sqft_lot15','yr_built','sqft_lot','view','waterfront','yr_renovated'],axis=1,inplace=True)

# %%
## Adjustments
f,ax=plt.subplots(figsize=(10, 10),nrows=5,ncols=2)
plt.subplots_adjust(hspace=1)
## Features
sns.boxplot(dataset['price'],data=dataset,ax=ax[0][0])
sns.boxplot(dataset['bedrooms'],data=dataset,ax=ax[0][1])
sns.boxplot(dataset['bathrooms'],data=dataset,ax=ax[1][0])
sns.boxplot(dataset['sqft_living'],data=dataset,ax=ax[1][1])
sns.boxplot(dataset['floors'],data=dataset,ax=ax[2][0])
sns.boxplot(dataset['grade'],data=dataset,ax=ax[2][1])
sns.boxplot(dataset['sqft_above'],data=dataset,ax=ax[3][0])
sns.boxplot(dataset['sqft_basement'],data=dataset,ax=ax[3][1])
sns.boxplot(dataset['lat'],data=dataset,ax=ax[4][0])
sns.boxplot(dataset['sqft_living15'],data=dataset,ax=ax[4][1])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
features = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_above', 'floors', 'grade', 'sqft_basement', 'lat', 'sqft_living15']
for feature in features:
  Q1 = dataset[feature].quantile(0.25)
  Q3 = dataset[feature].quantile(0.75)
  IQR = Q3-Q1
  lower_limit = Q1 - 1.5*IQR
  upper_limit = Q3 + 1.5*IQR
  dataset[feature] = np.where(dataset[feature]>upper_limit,upper_limit,dataset[feature])
  dataset[feature] = np.where(dataset[feature]<lower_limit,lower_limit,dataset[feature])

# %%
f,ax=plt.subplots(figsize=(10,10),nrows=5,ncols=2)
plt.subplots_adjust(hspace=1)
## Features
sns.boxplot(dataset['price'],data=dataset,ax=ax[0][0])
sns.boxplot(dataset['bedrooms'],data=dataset,ax=ax[0][1])

sns.boxplot(dataset['bathrooms'],data=dataset,ax=ax[1][0])
sns.boxplot(dataset['sqft_living'],data=dataset,ax=ax[1][1])

sns.boxplot(dataset['floors'],data=dataset,ax=ax[2][0])
sns.boxplot(dataset['grade'],data=dataset,ax=ax[2][1])

sns.boxplot(dataset['sqft_above'],data=dataset,ax=ax[3][0])
sns.boxplot(dataset['sqft_basement'],data=dataset,ax=ax[3][1])

sns.boxplot(dataset['lat'],data=dataset,ax=ax[4][0])
sns.boxplot(dataset['sqft_living15'],data=dataset,ax=ax[4][1])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
x=dataset.drop(['price'],axis=1)
y=dataset['price']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from xgboost import XGBRegressor

XGBR=XGBRegressor()
XGBR.fit(x_train,y_train)

from sklearn.model_selection import  cross_val_score,cross_val_predict
cv_XGBR=cross_val_score(XGBR,x_train,y_train,cv=10)
cv_XGBR_pred=cross_val_predict(XGBR,x_train,y_train,cv=10)

from sklearn.metrics import r2_score
r2_score(y_train,cv_XGBR_pred)
# Out:
# [11:00:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
XGBR_pred=XGBR.predict(x_test)
r2_score(y_test,XGBR_pred)
# Out:
# 0.8171625051851981

# %%
params = {"learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] }

from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(XGBR,param_distributions=params,n_iter=10,scoring='r2',n_jobs=-1,cv=5,verbose=3)
random_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   46.4s finished
# [11:15:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1, gamma=0,
#                                           importance_type='gain',
#                                           learning_rate=0.1, max_delta_step=0,
#                                           max_depth=3, min_child_weight=1,
# ...

# %%
random_search.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'gamma': 0.0,
#  'learning_rate': 0.1,
#  'max_depth': 8,
#  'min_child_weight': 5}

# %%
XGBR=XGBRegressor(colsample_bytree = 0.5,
 gamma= 0.0,
 learning_rate = 0.1,
 max_depth = 8,
 min_child_weight = 5)
XGBR.fit(x_train,y_train)
XGBR_pred=XGBR.predict(x_test)
r2_score(y_test,XGBR_pred)
# Out:
# [11:18:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.8319013975368021
